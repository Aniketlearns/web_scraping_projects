# %%
import requests
subnet_list = ['107.172.169.0'
, '107.172.169.1'
, '107.172.169.10'
, '107.172.169.100']


for subnet in subnet_list:
    ip_list = [{'http': f'http://yipitdata:R5R8TcXLUB@{subnet}:60000',
             'https': f'http://yipitdata:R5R8TcXLUB@{subnet}:60000'},]


    for proxy in ip_list:


        response = requests.get('https://quotes.toscrape.com/', proxies = proxy)
        print(response.text[:100])
        print(response,proxy)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta charset="UTF-8">
# 	<title>Quotes to Scrape</title>
#
# <Response [200]> {'http': 'http://yipitdata:R5R8TcXLUB@107.172.169.0:60000', 'https': 'http://yipitdata:R5R8TcXLUB@107.172.169.0:60000'}
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta charset="UTF-8">
# 	<title>Quotes to Scrape</title>
#
# <Response [200]> {'http': 'http://yipitdata:R5R8TcXLUB@107.172.169.1:60000', 'https': 'http://yipitdata:R5R8TcXLUB@107.172.169.1:60000'}
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta charset="UTF-8">
# 	<title>Quotes to Scrape</title>
#
# <Response [200]> {'http': 'http://yipitdata:R5R8TcXLUB@107.172.169.10:60000', 'https': 'http://yipitdata:R5R8TcXLUB@107.172.169.10:60000'}
# <!DOCTYPE html>
# <html lang="en">
# <head>
# 	<meta charset="UTF-8">
# 	<title>Quotes to Scrape</title>
#
# <Response [200]> {'http': 'http://yipitdata:R5R8TcXLUB@107.172.169.100:60000', 'https': 'http://yipitdata:R5R8TcXLUB@107.172.169.100:60000'}

# %% [markdown]
# <!-- https://www.trustpilot.com/categories -->

# %%
import requests
subnet_list = ['142.111.165.102',
                '142.111.165.118',
                '142.111.165.127',
                '142.111.165.14',
                '142.111.165.146',
                '142.111.165.147',
                '142.111.165.160',
                '142.111.165.174',
                '142.111.165.176']


for subnet in subnet_list:
    ip_list = [{'http': f'http://yipitdata:R5R8TcXLUB@{subnet}:60000',
             'https': f'http://yipitdata:R5R8TcXLUB@{subnet}:60000'},]


    for proxy in ip_list:


        response = requests.get('https://www.trustpilot.com/categories', proxies = proxy)
        print(response.text[:100])
        print(response,proxy)
# Out:
# {"error":true,"message":"Your request has been blocked as it has been identified as coming from a bo
# <Response [403]> {'http': 'http://yipitdata:R5R8TcXLUB@142.111.165.102:60000', 'https': 'http://yipitdata:R5R8TcXLUB@142.111.165.102:60000'}
# {"error":true,"message":"Your request has been blocked as it has been identified as coming from a bo
# <Response [403]> {'http': 'http://yipitdata:R5R8TcXLUB@142.111.165.118:60000', 'https': 'http://yipitdata:R5R8TcXLUB@142.111.165.118:60000'}
# {"error":true,"message":"Your request has been blocked as it has been identified as coming from a bo
# <Response [403]> {'http': 'http://yipitdata:R5R8TcXLUB@142.111.165.127:60000', 'https': 'http://yipitdata:R5R8TcXLUB@142.111.165.127:60000'}
# {"error":true,"message":"Your request has been blocked as it has been identified as coming from a bo
# <Response [403]> {'http': 'http://yipitdata:R5R8TcXLUB@142.111.165.14:60000', 'https': 'http://yipitdata:R5R8TcXLUB@142.111.165.14:60000'}
# ...

# %% [markdown]
# # selenium

# %%
import selenium
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import selenium
#
# ModuleNotFoundError: No module named 'selenium'

# %%
import selenium
from selenium import webdriver

driver = webdriver.Chrome()
driver.get("https://google.com")

search = driver.find_element("name", "q")
search.send_keys("RADHE RADHE")

# %% [markdown]
# # Playwright

# %%
from playwright.sync_api import sync_playwright

with sync_playwright() as p:
    browser = p.chromium.launch()
    page = browser.new_page()
    page.goto("https://google.com")

    page.locator('[name="q"]').fill("Playwright")
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[7], line 3
#       1 from playwright.sync_api import sync_playwright
# ----> 3 with sync_playwright() as p:
#       4     browser = p.chromium.launch()
#       5     page = browser.new_page()
#
# File ~/Documents/pythonProjects/web_scraping_test2026May/venv/lib/python3.13/site-packages/playwright/sync_api/_context_manager.py:47, in PlaywrightContextManager.__enter__(self)
#      45             self._own_loop = True
#      46         if self._loop.is_running():
# ---> 47             raise Error(
#      48                 """It looks like you are using Playwright Sync API inside the asyncio loop.
#      49 Please use the Async API instead."""
#      50             )
#      52         # Create a new fiber for the protocol dispatcher. It will be pumping events
# ...

# %%
import asyncio
from playwright.async_api import async_playwright

async def main():
    async with async_playwright() as p:
        browser = await p.chromium.launch()
        page = await browser.new_page()

        await page.goto("https://google.com")
        print(await page.title())

        await browser.close()

# %%
asyncio.run(main())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 asyncio.run(main())
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/asyncio/runners.py:191, in run(main, debug, loop_factory)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)    187     asyncio.run(main())
#     188 """
#     189 if events._get_running_loop() is not None:
#     190     # fail fast with short traceback
# --> 191     raise RuntimeError(
#     192         "asyncio.run() cannot be called from a running event loop")
#     194 with Runner(debug=debug, loop_factory=loop_factory) as runner:
#     195     return runner.run(main)
#
# RuntimeError: asyncio.run() cannot be called from a running event loop
# ...

# %%
import webbrowser
webbrowser.open('https://inventwithpython.com/')
# Out:
# True

# %%
import webbrowser
webbrowser.open('https://inventwithpython.com/')
# Out:
# True

# %%
# searchpypi.py - Opens several search results on pypi.org

import requests, sys, webbrowser, bs4

print('Searching...')  # Display text while downloading the search results page.
res = requests.get('https://pypi.org/search/?q=' + ' '.join(sys.argv[1:]))
res.raise_for_status()

# TODO: Retrieve top search result links.

# TODO: Open a browser tab for each result.
# Out:
# Searching...

# %%
# searchpypi.py - Opens several search results on pypi.org
import requests, sys, webbrowser, bs4
# --snip--
# Retrieve top search result links.
soup = bs4.BeautifulSoup(res.text, 'html.parser')
# Open a browser tab for each result.
link_elems = soup.select('.package-snippet')

# %% [markdown]
# # Open Web Browsers for Each Result

# %%
# searchpypi.py - Opens several search results on pypi.org
import requests, sys, webbrowser, bs4
# --snip--
# Open a browser tab for each result.
link_elems = soup.select('.package-snippet')
num_open = min(5, len(link_elems))
for i in range(num_open):
    url_to_open = 'https://pypi.org' + link_elems[i].get('href')
    print('Opening', url_to_open)
    webbrowser.open(url_to_open)
